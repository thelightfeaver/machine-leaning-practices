# %%
# %pip install pandas 
# %pip install numpy 
# %pip install matplotlib 
# %pip install seaborn
# %pip install scikit-learn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# %%
df = pd.read_csv('../datasets/cars.csv', encoding='latin-1')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Company Names              1218 non-null   object
#  1   Cars Names                 1218 non-null   object
#  2   Engines                    1218 non-null   object
#  3   CC/Battery Capacity        1215 non-null   object
#  4   HorsePower                 1218 non-null   object
#  5   Total Speed                1218 non-null   object
#  6   Performance(0 - 100 )KM/H  1212 non-null   object
#  7   Cars Prices                1218 non-null   object
#  8   Fuel Types                 1218 non-null   object
#  9   Seats                      1218 non-null   object
#  10  Torque                     1217 non-null   object
# dtypes: object(11)
# memory usage: 104.8+ KB

# %%
df.sample(20, random_state=42)
# Out:
#      Company Names                Cars Names                       Engines  \
# 541        Porsche             Cayenne Turbo            4.0L V8 Twin Turbo
# 259        HYUNDAI                    Sonata                 2.5L Inline-4
# 43     LAMBORGHINI             AVENTADOR SVJ                           V12
# 1008       Peugeot                   5008 GT                      Inline-4
# 584        Porsche                   Macan T           2.0L Turbo Inline-4
# 310     Volkswagen                   Crafter          2.0L Turbo Diesel I4
# 657    Tata Motors            Nexon EV Prime  Permanent Magnet Synchronous
# 1211         Mazda                Millenia S                       2.5L V6
# 210         TOYOTA                     VENZA                            I4
# 155            BMW                      118D                            I4
# 558        Porsche                    Taycan          Dual Electric Motors
# 411         Nissan               Rogue Sport                 2.0L Inline-4
# 1007       Peugeot                   2008 GT                      Inline-4
# 493         Nissan      Ariya Dual Motor AWD          Dual Electric Motors
# 1067    Mitsubishi                    Mirage                    1.2L MIVEC
# 522         Nissan                Silvia S13           1.8L Turbo Inline-4
# 543        Porsche  Cayenne Turbo S E-Hybrid      4.0L V8 + Electric Motor
# 551        Porsche            911 Carrera 4S        3.0L Twin-Turbo Flat-6
# 428         Nissan            X-Terra Pro-4X                 2.5L Inline-4
# 422         Nissan                   Skyline            3.0L V6 Twin-Turbo
#
#      CC/Battery Capacity    HorsePower Total Speed Performance(0 - 100 )KM/H  \
# 541              3996 cc        541 HP    286 km/h                   4.0 sec
# 259             2,500 cc        191 hp    240 km/h                     8 sec
# 43              6,498 cc        759 hp    350 km/h                   2.8 sec
# 1008            1,598 cc        180 hp    210 km/h                   8.2 sec
# 584              1984 cc        265 hp    233 km/h                       6.2
# 310              1968 cc  102 - 177 hp    160 km/h                  13.0 sec
# 657             30.2 kWh        129 hp    120 km/h                   9.4 sec
# 1211            2,500 cc        200 hp    220 km/h                   8.0 sec
# 210             2,494 cc        219 hp    200 km/h                   7.5 sec
# 155             1,995 cc        150 hp    216 km/h                   8.4 sec
# 558             79.2 kWh        402 hp    230 km/h                       5.4
# 411              1997 cc        141 HP    190 km/h                   9.8 sec
# 1007            1,199 cc        130 hp    200 km/h                   9.3 sec
# 493               87 kWh        389 HP    200 km/h                   5.1 sec
# 1067            1,200 cc         78 hp    170 km/h                  12.0 sec
# 522              1809 cc        175 HP    215 km/h                   6.8 sec
# 543     17.9 kWh Battery        670 HP    295 km/h                   3.6 sec
# 551              2981 cc        443 hp    306 km/h                       3.4
# 428              2498 cc        190 HP    175 km/h                  10.8 sec
# 422              2997 cc        400 HP    250 km/h                   5.0 sec
#
#             Cars Prices       Fuel Types Seats  Torque
# 541           $130,000            Petrol     5  770 Nm
# 259            $25,000     Petrol/Hybrid     5  250 Nm
# 43            $518,000            Petrol     2  720 Nm
# 1008           $40,000            Petrol     7  250 Nm
# 584            $63,000            Petrol     5  400 Nm
# 310            $40,000            Diesel     3  410 Nm
# 657            $22,000          Electric     5  245 Nm
# 1211  $30,000 - $35,000           Petrol     5  250 Nm
# 210            $33,400            Hybrid     5  400 Nm
# 155            $34,000            Diesel     5  380 Nm
# 558            $86,700          Electric     4  344 Nm
# 411            $24,960            Petrol     5  199 Nm
# 1007           $25,000            Petrol     5  230 Nm
# 493            $70,000          Electric     5  600 Nm
# 1067  $16,000 - $18,000           Petrol     5  100 Nm
# 522            $20,000            Petrol     4  230 Nm
# 543           $170,000   Hybrid (Petrol)     5  900 Nm
# 551           $113,300            Petrol     4  528 Nm
# 428            $40,000            Petrol     7  240 Nm
# 422            $50,000            Petrol     5  475 Nm

# %%
df.describe()
# Out:
#        Company Names Cars Names Engines CC/Battery Capacity HorsePower  \
# count           1218       1218    1218                1215       1218
# unique            37       1201     356                 311        456
# top           Nissan    Macan T      I4            2,000 cc     355 hp
# freq             149          2      64                  31         23
#
#        Total Speed Performance(0 - 100 )KM/H Cars Prices Fuel Types Seats  \
# count         1218                      1212        1218       1218  1218
# unique         114                       180         535         23    19
# top       250 km/h                   6.5 sec    $35,000      Petrol     5
# freq           145                        45          36        871   692
#
#         Torque
# count     1217
# unique     263
# top     400 Nm
# freq        72

# %%
# rename columns
df.rename(columns={'Company Names': 'company', 
                   'Cars Names': 'model', 
                   'Engines': 'engines', 
                   'CC/Battery Capacity': 'power_capacity',
                   'HorsePower': 'horsepower', 
                   'Total Speed': 'total_speed', 
                   'Performance(0 - 100 )KM/H': 'performance', 
                   'Cars Prices': 'prices',
                   'Fuel Types': 'fuel_types', 
                   'Seats': 'seats', 
                   'Torque': 'torque'}, 
          inplace=True)

# %%
import re
def extraer_valores(texto):
    match = re.search(r'(\d+(?:[\.,]\d+)?)', texto)  
    unidad = re.search(r'(cc|kwh)', texto, re.IGNORECASE)
    cantidad = match.group(1).replace(',', '.') if match else None
    unidad = unidad.group(1).lower() if unidad else None
    return float(cantidad), unidad

# %%
# clean columns
df['company'] = df['company'].str.capitalize()

# clean power_capacity
df["power_capacity"] = df["power_capacity"].str.lower()
df['power_capacity'] = df['power_capacity'].str.replace(r'[()]', '', regex=True)
df["power_capacity"] = df["power_capacity"].str.replace(r'standard', ' ', regex=True)
df[["power_capacity", "unit_power_capacity"]] = df["power_capacity"].str.extract(r'([\d,\.]+)\s*(\w+)', expand=True)
df["power_capacity"] = df["power_capacity"].str.replace(',', '').astype(float)

# clean prices
df["prices"] = df["prices"].str.replace(r'[$.,€]', '', regex=True)
df['prices'] = df['prices'].where(~df['prices'].str.contains('-', na=False), df['prices'].str.split('-', expand=True)[1])
df['prices'] = df['prices'].str.split(" ", expand=True)[0]

# clean performance
df['performance'] = df['performance'].str.lower()
df['performance'] = df['performance'].str.replace('sec', '')
df['performance'] = df['performance'].str.split(" ", expand=True)[0]

#clear torque
df['torque'] = df['torque'].str.lower()
df['torque'] = df['torque'].str.replace("nm", "")
df['torque'] = df['torque'].where(~df['torque'].str.contains("-", na=False), df['torque'].str.split('-',expand=True)[1])
df['torque'] = df['torque'].str.split(' ', expand=True)[0]

#clear horsepower
df['horsepower'] = df['horsepower'].str.lower().str.replace("hp", "")
df['horsepower'] = df['horsepower'].str.split('-', expand=True)[0]
df['horsepower'] = df['horsepower'].str.split(' ', expand=True)[0]
df["horsepower"] = df['horsepower'].str.replace(r'[^\d]', '', regex=True)


# clear top_speed
df["total_speed"] = df['total_speed'].str.replace(r'[^\d]', '', regex=True)

#clean seats
df['seats'] = df['seats'].str.split('+', expand=True)[0]
df['seats'] = df['seats'].str.split(' ', expand=True)[0]

# %%
df.dropna(inplace=True)
df = df[df != ''].dropna()
df.reset_index(drop=True, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1038 entries, 0 to 1037
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   company              1038 non-null   object
#  1   model                1038 non-null   object
#  2   engines              1038 non-null   object
#  3   power_capacity       1038 non-null   float64
#  4   horsepower           1038 non-null   object
#  5   total_speed          1038 non-null   object
#  6   performance          1038 non-null   object
#  7   prices               1038 non-null   object
#  8   fuel_types           1038 non-null   object
#  9   seats                1038 non-null   object
#  10  torque               1038 non-null   object
#  11  unit_power_capacity  1038 non-null   object
# dtypes: float64(1), object(11)
# memory usage: 97.4+ KB

# %%
# Convert horsepower to numeric
df['horsepower'] = pd.to_numeric(df['horsepower'], errors='coerce')
df['total_speed'] = df['total_speed'].astype(int)
df['performance'] = df['performance'].astype(float)
df['torque'] = pd.to_numeric(df['torque'], errors='coerce')
df['prices'] = pd.to_numeric(df['prices'], errors='coerce')

# %%
df
# Out:
#           company              model                             engines  \
# 0         Ferrari      SF90 STRADALE                                  V8
# 1     Rolls royce            PHANTOM                                 V12
# 2        Mercedes            GT 63 S                                  V8
# 3            Audi         AUDI R8 Gt                                 V10
# 4             Bmw       Mclaren 720s                                  V8
# ...           ...                ...                                 ...
# 1033       Toyota       Crown Signia                      2.5L Hybrid I4
# 1034       Toyota  4Runner (6th Gen)  2.4L Turbo I4 (i-FORCE MAX Hybrid)
# 1035       Toyota      Corolla Cross              2.0L Gas / 2.0L Hybrid
# 1036       Toyota             C-HR+                   1.8L / 2.0L Hybrid
# 1037       Toyota     RAV4 (6th Gen)        2.5L Hybrid / Plug-in Hybrid
#
#       power_capacity  horsepower  total_speed  performance     prices  \
# 0             3990.0         963          340          2.5  1100000.0
# 1             6749.0         563          250          5.3   460000.0
# 2             3982.0         630          250          3.2   161000.0
# 3             5204.0         602          320          3.6   253290.0
# 4             3994.0         710          341          2.9   499000.0
# ...              ...         ...          ...          ...        ...
# 1033          2487.0         240          180          7.6    43590.0
# 1034          2393.0         326          180          6.8    50000.0
# 1035          1987.0         169          190          8.0    25210.0
# 1036           179.0         140          180          7.9        NaN
# 1037          2487.0         219          200          6.0    29000.0
#
#                    fuel_types seats  torque unit_power_capacity
# 0             plug in hyrbrid     2   800.0                  cc
# 1                      Petrol     5   900.0                  cc
# 2                      Petrol     4   900.0                  cc
# 3                      Petrol     2   560.0                  cc
# 4                      Petrol     2   770.0                  cc
# ...                       ...   ...     ...                 ...
# 1033  Hybrid (Gas + Electric)     5   239.0                  cc
# 1034                   Hybrid     7   630.0                  cc
# 1035             Gas / Hybrid     5   190.0                  cc
# 1036                   Hybrid     5   190.0                   8
# 1037         Hybrid / Plug-in     5   221.0                  cc
#
# [1038 rows x 12 columns]

# %%
companys = df['company'].value_counts()
companys.plot(kind='bar', figsize=(12,6))
plt.title('Number of Cars by Company')
plt.xlabel('Company')
plt.ylabel('Number of Cars')
plt.show()
